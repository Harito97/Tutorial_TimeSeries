# %% [markdown]
# # 7.29
#
# The data file named robot contains a time series obtained from an industrial robot.
# The robot was put through a sequence of maneuvers, and the distance from a
# desired ending point was recorded in inches. This was repeated 324 times to form
# the time series.
# (a) Estimate the parameters of an AR(1) model for these data.
# (b) Estimate the parameters of an IMA(1,1) model for these data.
# (c) Compare the results from parts (a) and (b) in terms of AIC.

# %%
data(robot)
# Out:
# Warning message in data(robot):
# “data set ‘robot’ not found”

# %% [markdown]
# # 8.9
#
# The data file named robot contains a time series obtained from an industrial robot.
# The robot was put through a sequence of maneuvers, and the distance from a
# desired ending point was recorded in inches. This was repeated 324 times to form
# the time series. Compare the fits of an AR(1) model and an IMA(1,1) model for
# these data in terms of the diagnostic tests discussed in this chapter.

# %% [markdown]
# # 9.23
#
# The time series in the data file robot gives the final position in the “x-direction”
# after an industrial robot has finished a planned set of exercises. The measure-
# ments are expressed as deviations from a target position. The robot is put through
# this planned set of exercises in the hope that its behavior is repeatable and thus
# predictable.
# (a) Use an IMA(1,1) model to forecast five values ahead. Obtain 95% forecast
# limits also.
# (b) Display the forecasts, forecast limits, and actual values in a graph and inter-
# pret the results.
# (c) Now use an ARMA(1,1) model to forecast five values ahead and obtain 95%
# forecast limits. Compare these results with those obtained in part (a).

# %%
help.search("robot")
# Out:
# R Information
#
# Vignettes with name or keyword or title matching ‘robot’ using fuzzy
# matching:
#
#
# rprojroot::rprojroot    Finding files in project subdirectories
# vctrs::`type-size`      Prototypes and sizes
#
#
# Type 'vignette(PKG::FOO)' to inspect entries 'PKG::FOO'.
#
#
#
# Help files with alias or concept or title matching ‘robot’ using fuzzy
# matching:
#
#
# base::polyroot          Find Zeros of a Real or Complex Polynomial
#   Aliases: polyroot
# forecast::ocsb.test     Osborn, Chui, Smith, and Birchenhall Test for
#                         Seasonal Unit Roots
# forecast::plot.Arima    Plot characteristic roots from ARIMA model
# grid::grob              Create Grid Graphical Objects, aka "Grob"s
#   Aliases: grobTree
# gtable::gtable          Create a new grob table.
# MASS::polr              Ordered Logistic or Probit Regression
# methods::`methods-defunct`
#                         Defunct Functions in Package 'methods'
#   Aliases: getPrototype
# methods::completeSubclasses
#                         Utilities for Managing Class Definitions
#   Aliases: classPrototypeDef-class, makePrototypeFromClassDef,
#     reconcilePropertiesAndPrototype, defaultPrototype
# methods::representation
#                         Construct a Representation or a Prototype for a
#                         Class Definition
#   Aliases: prototype
# mgcv::gam.reparam       Finding stable orthogonal re-parameterization
#                         of the square root penalty.
# mgcv::mini.roots        Obtain square roots of penalty matrices
#   Aliases: mini.roots
# mgcv::mroot             Smallest square root of matrix
#   Aliases: mroot
# nlme::pdFactor          Square-Root Factor of a Positive-Definite
#                         Matrix
# nlme::pdFactor.reStruct
#                         Extract Square-Root Factor from Components of
#                         an reStruct Object
# nlme::pdMatrix          Extract Matrix or Square-Root Factor from a
#                         pdMat Object
# nlme::pdMatrix.reStruct
#                         Extract Matrix or Square-Root Factor from
#                         Components of an reStruct Object
# R.cache::getCacheRootPath
#                         Gets the root path to the file cache directory
#   Aliases: getCacheRootPath.default, getCacheRootPath
# R.cache::setCacheRootPath
#                         Sets the root path to the file cache directory
#   Aliases: setCacheRootPath.default, setCacheRootPath
# R.cache::setupCacheRootPath
#                         Interactively offers the user to set up the
#                         default root path
#   Aliases: setupCacheRootPath.default, setupCacheRootPath
# R.oo::BasicObject       A root class like Object but without references
# R.oo::Object            The root class that every class must inherit
#                         from
# R.utils::filePath       Construct the path to a file from components
#                         and expands Windows Shortcuts along the
#                         pathname from root to leaf
# robustbase::glmrobMqle.control
#                         Controlling Robust GLM Fitting by Different
#                         Methods
#   Aliases: glmrobMT.control
# robustbase::lmrob.control
#                         Tuning Parameters for lmrob() and Auxiliaries
#   Aliases: update.lmrobCtrl
# robustbase::nlrob.algorithms
#                         MM-, Tau-, CM-, and MTL- Estimators for
#                         Nonlinear Robust Regression
#   Aliases: nlrob.tau
# rprojroot::criteria     Prespecified criteria
#   Aliases: is_git_root, is_svn_root, is_vcs_root
# rprojroot::deprecated   Deprecated functions
#   Aliases: as.root_criterion, is.root_criterion
# rprojroot::find_root    Find the root of a directory hierarchy
#   Aliases: find_root, get_root_desc
# rprojroot::find_root_file
#                         File paths relative to the root of a directory
#                         hierarchy
#   Aliases: find_root_file, find_rstudio_root_file,
#     find_package_root_file, find_remake_root_file,
#     find_testthat_root_file
# rprojroot::root_criterion
#                         Is a directory the project root?
#   Aliases: root_criterion, is_root_criterion, as_root_criterion,
#     as_root_criterion.character, as_root_criterion.root_criterion,
#     |.root_criterion
# rprojroot::rprojroot-package
#                         rprojroot: Finding Files in Project
#                         Subdirectories
#   Aliases: rprojroot, rprojroot-package
# scales::transform_asn   Arc-sin square root transformation
# scales::transform_probability
#                         Probability transformation
#   Aliases: transform_probit, probit_trans
# scales::transform_sqrt
#                         Square-root transformation
# stats::PP.test          Phillips-Perron Test for Unit Roots
# stats::uniroot          One Dimensional Root (Zero) Finding
#   Aliases: uniroot
# styler::create_node_from_nested_root
#                         Convert a nested data frame into a node tree
#   Aliases: create_node_from_nested_root
# styler::set_arg_paths   Standardize paths in root
# survival::blogit        Bounded link functions
#   Aliases: bprobit
# tcltk::TclInterface     Low-level Tcl/Tk Interface
#   Aliases: .TkRoot
# tinytex::install_tinytex
#                         Install/Uninstall TinyTeX
#   Aliases: tinytex_root
# TSA::robot              The distance of a robot from a desired position
#                         / time series
#   Aliases: robot
# tseries::pp.test        Phillips-Perron Unit Root Test
# urca::.spcv             Critical values for Schmidt and Phillips Unit
#                         Root Test
# urca::MacKinnonPValues
#                         MacKinnon's Unit Root p Values
#   Aliases: punitroot, qunitroot, unitrootTable
# urca::show.urca         Function to show objects of classes for unit
#                         root tests
# urca::ur.df             Augmented-Dickey-Fuller Unit Root Test
# urca::ur.ers            Elliott, Rothenberg and Stock Unit Root Test
# urca::ur.kpss           Kwiatkowski et al. Unit Root Test
# urca::ur.pp             Phillips and Perron Unit Root Test
# urca::ur.sp             Schmidt and Phillips Unit Root Test
# urca::ur.za             Zivot and Andrews Unit Root Test
# utils::prompt           Produce Prototype of an R Documentation File
# vctrs::vec_assert       Assert an argument has known prototype and/or
#                         size
# vctrs::vec_cbind_frame_ptype
#                         Frame prototype
# vctrs::vec_ptype        Find the prototype of a set of vectors
# xfun::from_root         Get the relative path of a path in a project
#                         relative to the current working directory
#   Aliases: from_root
# xfun::magic_path        Find a file or directory under a root directory
# xfun::proj_root         Return the (possible) root directory of a
#                         project
#   Aliases: proj_root, root_rules
# xml2::xml_children      Navigate around the family tree.
#   Aliases: xml_root
# xml2::xml_new_document
#                         Create a new document, possibly with a root
#                         node
#   Aliases: xml_new_root
#
#
# Type '?PKG::FOO' to inspect entries 'PKG::FOO', or 'TYPE?PKG::FOO' for
# entries like 'PKG::FOO-TYPE'.
